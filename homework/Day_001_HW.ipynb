# %% [markdown]
# ### 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# #### 1. 你選的這組資料為何重要
# 我挑選的 Competitions 是 `iWildCam 2019 - FGVC6`，是在美國西南部和美國西北部利用野生動物相機，也許能夠利用其資料分析出各個野生區域中的物種遷徙狀況、是否有不曾出現的新物種或外來種，能得出各種不同的資訊。
#
# #### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 資料來源主要來自 Erin Boydston (USGS), Justin Brown (NPS), iNaturalist, and the Idaho Department of Fish and Game (IDFG)。
#
# #### 3. 蒐集而來的資料型態為何
#
# 1. 分成訓練用圖檔以及測試用圖檔，其中包含了 153,730 張圖片。
# 2. 分成訓練用資料以及測試用資料 csv，訓練資料有包含：物種類別、拍照時間、圖片檔名、區域等資訊。
#
# #### 4.這組資料想解決的問題如何評估
#
# 1. 透過 AI 去分析物種在新的野生區域中或是不同的環境中能夠分類出不同的物種，並將其標記。

# %% [markdown]
# ### 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# #### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 找出 `熱門叫車地點`和`需求預測`，根據時段、區域、天氣、活動或是節慶等，對不同區域的司機給予不同的建議，有需求則提出供給，讓乘客能夠方便快速找到司機提供服務。
#
# #### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 在使用 App 叫車、從電話語音叫車或是在 App 裡只搜尋未叫車時，記下時間、下車地點、上車區域、天氣等資訊，並去識別化，將乘客的資料保密。若有特別時段與時間意外的很多資料，將可以調查是否當時有活動節慶等外部因素產生。
#
# #### 3. 蒐集而來的資料型態為何
#
# 一筆叫車紀錄或搜尋紀錄為 1 row 製作成 CSV 檔
#
# #### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# 利用分析後的資料，觀察平時載客率低的司機，根據大數據分析後推薦的載客點，看其成長比率是否有上漲。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import math

def mean_squared_error(y, y_hat):
    return math.pow(sum(y - y_hat),2) / len(y)

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 243.659
# The Mean absolute error is 11.543
